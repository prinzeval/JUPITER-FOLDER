# %%
import pandas as pd 
import glob
import os
import urllib.request
import xml.etree.ElementTree as ET
from datetime import datetime

# %%
import pandas as pd
import urllib.request
import zipfile

url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0221EN-SkillsNetwork/labs/module%206/Lab%20-%20Extract%20Transform%20Load/data/datasource.zip"
file_name = "datasource.zip"
extension = ("csv","json")

# Download the zip file
urllib.request.urlretrieve(url, file_name)

# Extract data from the zip file
with zipfile.ZipFile(file_name, 'r') as zip_ref:
    files = zip_ref.namelist()
    for file in files:
        if file.endswith(extension):
            with zip_ref.open(file) as extracted_file:
                df = pd.read_csv(extracted_file)
                print(df)
# Out:
#        car_model  year_of_manufacture         price    fuel
# 0           ritz                 2014   5000.000000  Petrol
# 1            sx4                 2013   7089.552239  Diesel
# 2           ciaz                 2017  10820.895522  Petrol
# 3        wagon r                 2011   4253.731343  Petrol
# 4          swift                 2014   6865.671642  Diesel
# 5  vitara brezza                 2018  13805.970149  Diesel
# 6           ciaz                 2015  10074.626866  Petrol
# 7        s cross                 2015   9701.492537  Diesel
# 8           ciaz                 2016  13059.701493  Diesel
# 9           ciaz                 2015  11119.402985  Diesel
#   car_model  year_of_manufacture         price    fuel
# 0  alto 800                 2017   4253.731343  Petrol
# 1      ciaz                 2015  10223.880597  Diesel
# 2      ciaz                 2015  11194.029851  Petrol
# 3    ertiga                 2015   9104.477612  Petrol
# 4     dzire                 2009   3358.208955  Petrol
# 5    ertiga                 2016  11567.164179  Diesel
# 6    ertiga                 2015  10820.895522  Diesel
# 7    ertiga                 2016  11567.164179  Diesel
# 8   wagon r                 2015   4850.746269     CNG
# 9       sx4                 2010   3955.223881  Petrol
#   car_model  year_of_manufacture         price    fuel
# 0  alto k10                 2016   4253.731343  Petrol
# 1     ignis                 2017   7313.432836  Petrol
# 2       sx4                 2011   6567.164179  Petrol
# 3  alto k10                 2014   3731.343284  Petrol
# 4   wagon r                 2013   4328.358209  Petrol
# 5     swift                 2011   4477.611940  Petrol
# 6     swift                 2013   6194.029851  Petrol
# 7     swift                 2017   8955.223881  Petrol
# 8  alto k10                 2010   2910.447761  Petrol
# 9      ciaz                 2015  11119.402985  Diesel
#        {"car_model":"ritz"  year_of_manufacture:2012  price:4626.8656716418  \
# 0      {"car_model":"ritz"  year_of_manufacture:2011  price:3507.4626865672
# 1     {"car_model":"swift"  year_of_manufacture:2014  price:7388.0597014925
# 2    {"car_model":"ertiga"  year_of_manufacture:2014   price:8955.223880597
# 3     {"car_model":"dzire"  year_of_manufacture:2014  price:8208.9552238806
# 4       {"car_model":"sx4"  year_of_manufacture:2011  price:4402.9850746269
# 5     {"car_model":"dzire"  year_of_manufacture:2015  price:6940.2985074627
# 6       {"car_model":"800"  year_of_manufacture:2003   price:522.3880597015
# 7  {"car_model":"alto k10"  year_of_manufacture:2016  price:4477.6119402985
# 8       {"car_model":"sx4"  year_of_manufacture:2003  price:3358.2089552239
#
#    fuel:"Diesel"}
# 0  fuel:"Petrol"}
# 1  fuel:"Diesel"}
# 2  fuel:"Diesel"}
# 3  fuel:"Diesel"}
# 4     fuel:"CNG"}
# 5  fuel:"Petrol"}
# 6  fuel:"Petrol"}
# 7  fuel:"Petrol"}
# 8  fuel:"Petrol"}
#      {"car_model":"baleno"  year_of_manufacture:2016   price:8731.3432835821  \
# 0  {"car_model":"alto k10"  year_of_manufacture:2014   price:3805.9701492537
# 1       {"car_model":"sx4"  year_of_manufacture:2008    price:2910.447761194
# 2     {"car_model":"dzire"  year_of_manufacture:2014   price:8208.9552238806
# 3      {"car_model":"omni"  year_of_manufacture:2012    price:1865.671641791
# 4      {"car_model":"ciaz"  year_of_manufacture:2014  price:11194.0298507463
# 5      {"car_model":"ritz"  year_of_manufacture:2013    price:3955.223880597
# 6   {"car_model":"wagon r"  year_of_manufacture:2006   price:1567.1641791045
# 7    {"car_model":"ertiga"  year_of_manufacture:2015   price:8656.7164179104
# 8      {"car_model":"ciaz"  year_of_manufacture:2017  price:11567.1641791045
#
#    fuel:"Petrol"}
# 0  fuel:"Petrol"}
# 1  fuel:"Petrol"}
# 2  fuel:"Diesel"}
# 3  fuel:"Petrol"}
# 4  fuel:"Petrol"}
# 5  fuel:"Petrol"}
# 6  fuel:"Petrol"}
# 7  fuel:"Petrol"}
# 8  fuel:"Petrol"}
#         {"car_model":"fortuner"  year_of_manufacture:2012  \
# 0       {"car_model":"fortuner"  year_of_manufacture:2015
# 1         {"car_model":"innova"  year_of_manufacture:2017
# 2       {"car_model":"fortuner"  year_of_manufacture:2013
# 3         {"car_model":"innova"  year_of_manufacture:2005
# 4  {"car_model":"corolla altis"  year_of_manufacture:2009
# 5    {"car_model":"etios cross"  year_of_manufacture:2015
# 6  {"car_model":"corolla altis"  year_of_manufacture:2010
# 7        {"car_model":"etios g"  year_of_manufacture:2014
# 8       {"car_model":"fortuner"  year_of_manufacture:2014
#
#    price:22238.8059701493  fuel:"Diesel"}
# 0  price:34328.3582089552  fuel:"Diesel"}
# 1   price:26865.671641791  fuel:"Diesel"}
# 2  price:23880.5970149254  fuel:"Diesel"}
# 3   price:4104.4776119403  fuel:"Petrol"}
# 4   price:5373.1343283582  fuel:"Petrol"}
# 5   price:6716.4179104478  fuel:"Petrol"}
# 6    price:7089.552238806  fuel:"Petrol"}
# 7   price:6119.4029850746  fuel:"Petrol"}
# 8  price:29835.8208955224  fuel:"Diesel"}

# %%
print(df)
# Out:
#         {"car_model":"fortuner"  year_of_manufacture:2012  \
# 0       {"car_model":"fortuner"  year_of_manufacture:2015
# 1         {"car_model":"innova"  year_of_manufacture:2017
# 2       {"car_model":"fortuner"  year_of_manufacture:2013
# 3         {"car_model":"innova"  year_of_manufacture:2005
# 4  {"car_model":"corolla altis"  year_of_manufacture:2009
# 5    {"car_model":"etios cross"  year_of_manufacture:2015
# 6  {"car_model":"corolla altis"  year_of_manufacture:2010
# 7        {"car_model":"etios g"  year_of_manufacture:2014
# 8       {"car_model":"fortuner"  year_of_manufacture:2014
#
#    price:22238.8059701493  fuel:"Diesel"}
# 0  price:34328.3582089552  fuel:"Diesel"}
# 1   price:26865.671641791  fuel:"Diesel"}
# 2  price:23880.5970149254  fuel:"Diesel"}
# 3   price:4104.4776119403  fuel:"Petrol"}
# 4   price:5373.1343283582  fuel:"Petrol"}
# 5   price:6716.4179104478  fuel:"Petrol"}
# 6    price:7089.552238806  fuel:"Petrol"}
# 7   price:6119.4029850746  fuel:"Petrol"}
# 8  price:29835.8208955224  fuel:"Diesel"}
